# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../Data/Train_data_Update.csv", index_col = "Start_date")

# %%
df.columns
# Out:
# Index(['Year', 'Count', 'Days_Open', 'Avg_Count', 'News_Count',
#        'Vis_change_rate', 'big_data_newsCount', 'prev_count', 'mid_count',
#        'after_count', 'WeekDay', 'Avg_Tmp', 'High_Tmp', 'Low_Tmp', 'Month',
#        'Day'],
#       dtype='object')

# %%
weather = pd.read_csv("../Data/weather_mean_pop.csv")

# %%
weather.head()
# Out:
#    Year     pop   avg_temp  high_temp   low_temp  temp_range  Portrait_temp  \
# 0  2000  188046  26.980000  32.020000  23.360000    8.710000      22.690000
# 1  2001  245338  25.950000  30.450000  22.150000    8.300000      20.940000
# 2  2002  209510  22.580000  25.220000  20.850000    4.370000      20.050000
# 3  2003  151235  23.772727  27.700000  20.554545    7.145455      18.945455
# 4  2004  126596  28.227273  33.327273  24.363636    8.963636      22.054545
#
#     humidity  cloudAmount  hourSolarRadiation  hourSunshine  avg_windSpeed\n  \
# 0  75.980000     6.570000           16.881000      5.810000        11.340000
# 1  72.090000     5.410000           15.950000      5.710000         9.770000
# 2  87.600000     9.180000            7.779000      0.470000         6.000000
# 3  74.890909     6.027273           15.190909      4.836364         8.500000
# 4  69.072727     4.036364           19.643636      7.809091         5.472727
#
#    high_windspeed      high_  evaporation_amount   rainfall  \
# 0       23.675000  38.175000            2.170000   0.487500
# 1       21.270000  34.300000            4.030000   5.010000
# 2       15.300000  23.700000            1.980000  11.480000
# 3       19.245455  32.100000            3.145455   2.400000
# 4       16.581818  28.890909            5.263636   2.454545
#
#    groundTemperature  Month  Day  Days_Open
# 0          31.250000      8   11         10
# 1          28.110000      8   11         10
# 2          26.340000      8    9         10
# 3          30.136364      8    7         11
# 4          30.445455      7   31         11

# %%
weather.columns = ['Year', 'Count', 'avg_temp', 'high_temp', 'low_temp', 'temp_range',
       'Portrait_temp', 'humidity', 'cloudAmount', 'hourSolarRadiation',
       'hourSunshine', 'avg_windSpeed\n', 'high_windspeed', 'high_',
       'evaporation_amount', 'rainfall', 'groundTemperature', 'Month', 'Day',
       'Days_Open']

# %%
weather["Avg_Count"] = weather['pop'].astype(int) / weather['Days_Open'].astype(int)

# %%
weather.head()
# Out:
#    Year     pop   avg_temp  high_temp   low_temp  temp_range  Portrait_temp  \
# 0  2000  188046  26.980000  32.020000  23.360000    8.710000      22.690000
# 1  2001  245338  25.950000  30.450000  22.150000    8.300000      20.940000
# 2  2002  209510  22.580000  25.220000  20.850000    4.370000      20.050000
# 3  2003  151235  23.772727  27.700000  20.554545    7.145455      18.945455
# 4  2004  126596  28.227273  33.327273  24.363636    8.963636      22.054545
#
#     humidity  cloudAmount  hourSolarRadiation  ...  avg_windSpeed\n  \
# 0  75.980000     6.570000           16.881000  ...        11.340000
# 1  72.090000     5.410000           15.950000  ...         9.770000
# 2  87.600000     9.180000            7.779000  ...         6.000000
# 3  74.890909     6.027273           15.190909  ...         8.500000
# 4  69.072727     4.036364           19.643636  ...         5.472727
#
#    high_windspeed      high_  evaporation_amount   rainfall  \
# 0       23.675000  38.175000            2.170000   0.487500
# 1       21.270000  34.300000            4.030000   5.010000
# 2       15.300000  23.700000            1.980000  11.480000
# 3       19.245455  32.100000            3.145455   2.400000
# 4       16.581818  28.890909            5.263636   2.454545
#
#    groundTemperature  Month  Day  Days_Open     Avg_Count
# 0          31.250000      8   11         10  18804.600000
# 1          28.110000      8   11         10  24533.800000
# 2          26.340000      8    9         10  20951.000000
# 3          30.136364      8    7         11  13748.636364
# 4          30.445455      7   31         11  11508.727273
#
# [5 rows x 21 columns]

# %%
weather.columns
# Out:
# Index(['Year', 'pop', 'avg_temp', 'high_temp', 'low_temp', 'temp_range',
#        'Portrait_temp', 'humidity', 'cloudAmount', 'hourSolarRadiation',
#        'hourSunshine', 'avg_windSpeed\n', 'high_windspeed', 'high_',
#        'evaporation_amount', 'rainfall', 'groundTemperature', 'Month', 'Day',
#        'Days_Open', 'Avg_Count'],
#       dtype='object')

# %% [markdown]
# #### Checking for Linearity
# Before you execute a linear regression model, it is advisable to validate that certain assumptions are met.
#
# As noted earlier, you may want to check that a linear relationship exists between the dependent variable and the independent variable/s.

# %%
plt.scatter(weather['avg_temp'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs avg_temp', fontsize=14)
plt.xlabel('avg_temp', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()
 
plt.scatter(weather['temp_range'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs temp_range', fontsize=14)
plt.xlabel('temp_range', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(weather['Portrait_temp'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs Portrait_temp', fontsize=14)
plt.xlabel('Portrait_temp', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(weather['humidity'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs humidity', fontsize=14)
plt.xlabel('humidity', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(weather['cloudAmount'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs cloudAmount', fontsize=14)
plt.xlabel('cloudAmount', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()


plt.scatter(weather['hourSolarRadiation'],weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs hourSolarRadiation', fontsize=14)
plt.xlabel('hourSolarRadiation', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()


plt.scatter(weather['avg_windSpeed\n'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs avg_windSpeed', fontsize=14)
plt.xlabel('avg_windSpeed', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()


plt.scatter(weather['evaporation_amount'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs evaporation_amount', fontsize=14)
plt.xlabel('evaporation_amount', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(weather['rainfall'], weather['Avg_Count'], color='red')
plt.title('Visitors per Day Vs rainfall', fontsize=14)
plt.xlabel('rainfall', fontsize=14)
plt.ylabel('Visitors', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Performing the Multiple Linear Regression

# %%
from sklearn import linear_model
import statsmodels.api as sm

# %%
weather.head()
# Out:
#    Year     pop   avg_temp  high_temp   low_temp  temp_range  Portrait_temp  \
# 0  2000  188046  26.980000  32.020000  23.360000    8.710000      22.690000
# 1  2001  245338  25.950000  30.450000  22.150000    8.300000      20.940000
# 2  2002  209510  22.580000  25.220000  20.850000    4.370000      20.050000
# 3  2003  151235  23.772727  27.700000  20.554545    7.145455      18.945455
# 4  2004  126596  28.227273  33.327273  24.363636    8.963636      22.054545
#
#     humidity  cloudAmount  hourSolarRadiation  ...  avg_windSpeed\n  \
# 0  75.980000     6.570000           16.881000  ...        11.340000
# 1  72.090000     5.410000           15.950000  ...         9.770000
# 2  87.600000     9.180000            7.779000  ...         6.000000
# 3  74.890909     6.027273           15.190909  ...         8.500000
# 4  69.072727     4.036364           19.643636  ...         5.472727
#
#    high_windspeed      high_  evaporation_amount   rainfall  \
# 0       23.675000  38.175000            2.170000   0.487500
# 1       21.270000  34.300000            4.030000   5.010000
# 2       15.300000  23.700000            1.980000  11.480000
# 3       19.245455  32.100000            3.145455   2.400000
# 4       16.581818  28.890909            5.263636   2.454545
#
#    groundTemperature  Month  Day  Days_Open     Avg_Count
# 0          31.250000      8   11         10  18804.600000
# 1          28.110000      8   11         10  24533.800000
# 2          26.340000      8    9         10  20951.000000
# 3          30.136364      8    7         11  13748.636364
# 4          30.445455      7   31         11  11508.727273
#
# [5 rows x 21 columns]

# %%
#df.drop('Year', axis = 1, inplace=True)
#df.drop('Count', axis = 1, inplace=True)
a = df['Avg_Count'].values
df.drop('Avg_Count', axis = 1, inplace=True)

# %%
df['Avg_Count'] = a

# %%
weather.shape
# Out:
# (22, 21)

# %%
weather.iloc[:, 0:21]
# Out:
#     Year     pop   avg_temp  high_temp   low_temp  temp_range  Portrait_temp  \
# 0   2000  188046  26.980000  32.020000  23.360000    8.710000      22.690000
# 1   2001  245338  25.950000  30.450000  22.150000    8.300000      20.940000
# 2   2002  209510  22.580000  25.220000  20.850000    4.370000      20.050000
# 3   2003  151235  23.772727  27.700000  20.554545    7.145455      18.945455
# 4   2004  126596  28.227273  33.327273  24.363636    8.963636      22.054545
# 5   2005  283333  25.840000  29.480000  23.150000    6.830000      22.780000
# 6   2006  317012  26.740000  31.530000  23.070000    8.460000      22.090000
# 7   2007  195251  27.520000  32.380000  23.700000    8.680000      22.800000
# 8   2008   81291  18.233333  24.666667  10.900000   13.766667       8.866667
# 9   2009  135169  17.166667  25.600000   8.833333   16.766667       7.366667
# 10  2009  278189  14.560000  21.250000   9.200000   12.050000       7.750000
# 11  2010  130000  11.933333  18.933333   5.466667   13.466667       3.200000
# 12  2010  117929  17.775000  23.775000  13.425000   10.350000      11.825000
# 13  2011  153024  14.925000  21.850000   9.375000   12.475000       6.825000
# 14  2012   84252  15.266667  20.366667  11.100000    9.266667       7.766667
# 15  2013  151878  29.066667  33.300000  25.600000    7.700000      23.966667
# 16  2014   48000   5.333333  10.166667   0.700000    9.466667      -2.033333
# 17  2015  167800  16.900000  24.300000  11.200000   13.100000       6.660000
# 18  2016  170210  16.000000  20.133333  11.833333    8.300000       9.866667
# 19  2017  222864  14.200000  20.775000   8.950000   11.825000       4.000000
# 20  2018  230000  12.450000  20.325000   6.650000   13.675000       1.825000
# 21  2019  240000  15.850000  22.350000  11.075000   11.275000       6.150000
#
#      humidity  cloudAmount  hourSolarRadiation  ...  avg_windSpeed\n  \
# 0   75.980000     6.570000           16.881000  ...        11.340000
# 1   72.090000     5.410000           15.950000  ...         9.770000
# 2   87.600000     9.180000            7.779000  ...         6.000000
# 3   74.890909     6.027273           15.190909  ...         8.500000
# 4   69.072727     4.036364           19.643636  ...         5.472727
# 5   79.170000     6.670000           14.064000  ...         4.360000
# 6   71.170000     5.470000           17.689000  ...         5.800000
# 7   73.440000     5.220000           18.866000  ...         4.740000
# 8   35.766667     5.000000           18.526667  ...        11.266667
# 9   35.200000     2.200000           22.003333  ...         5.766667
# 10  67.910000     3.300000           14.504000  ...         5.330000
# 11  51.600000     3.100000           20.953333  ...         6.466667
# 12  75.700000     4.550000           14.927500  ...         4.325000
# 13  68.825000     1.900000           15.475000  ...         4.500000
# 14  79.366667     5.300000           10.740000  ...         6.700000
# 15  83.000000     3.800000           19.233333  ...         5.766667
# 16  63.733333     5.900000           10.753333  ...         7.566667
# 17  77.440000     0.820000           14.758000  ...         3.160000
# 18  73.100000     8.033333           10.736667  ...         7.666667
# 19  69.950000     1.375000           16.192500  ...         5.150000
# 20  72.075000     2.600000           16.847500  ...         3.050000
# 21  78.025000     4.666667           14.812500  ...         2.400000
#
#     high_windspeed      high_  evaporation_amount   rainfall  \
# 0        23.675000  38.175000            2.170000   0.487500
# 1        21.270000  34.300000            4.030000   5.010000
# 2        15.300000  23.700000            1.980000  11.480000
# 3        19.245455  32.100000            3.145455   2.400000
# 4        16.581818  28.890909            5.263636   2.454545
# 5        15.840000  28.460000            2.780000  17.450000
# 6        12.970000  24.490000            4.740000   0.490000
# 7        12.380000  22.180000            4.540000   0.700000
# 8        24.966667  39.866667            5.000000   0.000000
# 9        16.300000  30.833333            5.133333   0.000000
# 10       14.830000  27.670000            2.520000   1.770000
# 11       17.300000  32.900000            3.133333   0.166667
# 12       10.525000  19.175000            2.125000   0.125000
# 13       11.800000  20.675000            2.400000   0.000000
# 14       15.800000  27.833333            1.866667   7.200000
# 15       18.366667  32.766667            4.800000   4.366667
# 16       18.733333  33.633333            1.500000   0.566667
# 17        8.660000  16.340000            0.480000   0.000000
# 18       17.033333  28.200000            0.000000   0.333333
# 19       12.500000  26.200000            0.000000   0.000000
# 20        7.300000  14.950000            0.000000   0.000000
# 21       10.525000  21.625000            0.000000   0.000000
#
#     groundTemperature  Month  Day  Days_Open     Avg_Count
# 0           31.250000      8   11         10  18804.600000
# 1           28.110000      8   11         10  24533.800000
# 2           26.340000      8    9         10  20951.000000
# 3           30.136364      8    7         11  13748.636364
# 4           30.445455      7   31         11  11508.727273
# 5           31.030000      8   12         10  28333.300000
# 6           26.120000      8   11         10  31701.200000
# 7           19.820000      8   15          5  39050.200000
# 8           18.166667      4   19          3  27097.000000
# 9           15.333333      4   10          3  45056.333333
# 10          17.580000     10    9         10  27818.900000
# 11          18.033333      4   23          3  43333.333333
# 12          19.575000     10    7          4  29482.250000
# 13          17.975000     10    6          4  38256.000000
# 14          13.766667     10   26          3  28084.000000
# 15          17.233333      8    9          3  50626.000000
# 16          17.033333     11   12          3  16000.000000
# 17          16.300000     10   17          5  33560.000000
# 18          14.700000     10   22          4  42552.500000
# 19          17.675000     10   21          4  55716.000000
# 20           0.000000     10   19          4  57500.000000
# 21           0.000000     10   18          4  60000.000000
#
# [22 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Count', 'Days_Open', 'Avg_Count', 'News_Count',
#        'Vis_change_rate', 'big_data_newsCount', 'prev_count', 'mid_count',
#        'after_count', 'WeekDay', 'Avg_Tmp', 'High_Tmp', 'Low_Tmp', 'Month',
#        'Day'],
#       dtype='object')

# %%
#fill NA with 0 
weather = weather.fillna(0)

# %%
X = weather.iloc[:, 0:20] 
Y = weather['Avg_Count']

# %%
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -303992.0500906729
# Coefficients:
#  [ 2.11838529e+02  1.15292390e-01 -2.79503124e+03  4.22237629e+04
#  -4.02218415e+04 -4.42217417e+04  1.52988391e+03 -6.72094002e+02
#  -1.33564692e+03  1.17300514e+03  2.10304726e+03 -1.40052951e+03
#   9.42338127e+02 -3.41834357e+02 -6.22123386e+03  9.43643817e+02
#  -5.09588857e+02 -1.49877462e+03 -1.29909598e+02 -3.17518348e+03]

# %%
weather.columns
# Out:
# Index(['Year', 'pop', 'avg_temp', 'high_temp', 'low_temp', 'temp_range',
#        'Portrait_temp', 'humidity', 'cloudAmount', 'hourSolarRadiation',
#        'hourSunshine', 'avg_windSpeed\n', 'high_windspeed', 'high_',
#        'evaporation_amount', 'rainfall', 'groundTemperature', 'Month', 'Day',
#        'Days_Open', 'Avg_Count'],
#       dtype='object')

# %%
# prediction with sklearn
days_open = 4
News_count = 400
WeekDay = 4
big_data_news = 40
avg_temp = 21
print ('Predicted Visitor Number per day: \n', regr.predict([[days_open, News_count,WeekDay, big_data_news, avg_temp]]))
# Out:
# Predicted Visitor Number:
#  [91735.30828452]

# %%
# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Avg_Count   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     3.631
# Date:                Tue, 29 Oct 2019   Prob (F-statistic):              0.394
# Time:                        18:06:35   Log-Likelihood:                -193.70
# No. Observations:                  22   AIC:                             429.4
# Df Residuals:                       1   BIC:                             452.3
# Df Model:                          20
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               -3.04e+05   6.24e+06     -0.049      0.969   -7.96e+07     7.9e+07
# Year                 211.8385   2974.446      0.071      0.955   -3.76e+04     3.8e+04
# pop                    0.1153      0.099      1.164      0.452      -1.143       1.374
# avg_temp           -2795.0312    4.1e+04     -0.068      0.957   -5.24e+05    5.18e+05
# high_temp           4.222e+04    1.4e+05      0.302      0.813   -1.73e+06    1.82e+06
# low_temp           -4.022e+04   1.58e+05     -0.255      0.841   -2.05e+06    1.97e+06
# temp_range         -4.422e+04   1.38e+05     -0.322      0.802   -1.79e+06     1.7e+06
# Portrait_temp       1529.8839   8629.820      0.177      0.888   -1.08e+05    1.11e+05
# humidity            -672.0940   1880.502     -0.357      0.781   -2.46e+04    2.32e+04
# cloudAmount        -1335.6469   1.29e+04     -0.103      0.934   -1.65e+05    1.63e+05
# hourSolarRadiation  1173.0051    1.1e+04      0.106      0.933   -1.39e+05    1.41e+05
# hourSunshine        2103.0473   1.14e+04      0.184      0.884   -1.43e+05    1.47e+05
# avg_windSpeed
#      -1400.5295   5158.041     -0.272      0.831   -6.69e+04    6.41e+04
# high_windspeed       942.3381   5855.398      0.161      0.898   -7.35e+04    7.53e+04
# high_               -341.8344   3008.681     -0.114      0.928   -3.86e+04    3.79e+04
# evaporation_amount -6221.2339   5773.025     -1.078      0.476   -7.96e+04    6.71e+04
# rainfall             943.6438   5129.534      0.184      0.884   -6.42e+04    6.61e+04
# groundTemperature   -509.5889   2718.343     -0.187      0.882    -3.5e+04     3.4e+04
# Month              -1498.7746   1.35e+04     -0.111      0.930   -1.74e+05    1.71e+05
# Day                 -129.9096    489.349     -0.265      0.835   -6347.680    6087.861
# Days_Open          -3175.1835   2293.285     -1.385      0.398   -3.23e+04     2.6e+04
# ==============================================================================
# Omnibus:                        4.488   Durbin-Watson:                   1.580
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                2.534
# Skew:                           0.534   Prob(JB):                        0.282
# Kurtosis:                       4.275   Cond. No.                     7.40e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# ### Model Evaluation

# %%
# import sk learn train test split
from sklearn.model_selection import train_test_split

# Assign variables to capture train test split output
X_train, X_test, y_train, y_test = train_test_split(X,Y)

# %%
#Import SK learn linear regression
from sklearn.linear_model import LinearRegression

# Instantiate
linreg = LinearRegression()

# Fit model to training data 
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#Assign feature cols
feature_cols = ['Days_Open','News_Count','Avg_Tmp','WeekDay','big_data_newsCount']

#print y-intercept
print(linreg.intercept_)

#print the beta coefficients in same order as passed 
print(linreg.coef_)

# Zip can pair feature names and coefficients together
zip(feature_cols, linreg.coef_)
# Out:
# 5357275.298686987
# [ 4.43658827e-07 -2.26774047e+03 -1.28341321e-01 -1.17114579e+04
#  -7.07382711e+02 -4.44054805e+02 -1.20683700e+04  1.75824280e+04
#  -4.20549779e+03 -2.31421272e+04 -1.76297231e+03  1.09337976e+03
#   8.70010053e+02 -8.24503698e+02  3.44950612e+02 -2.55981514e+04
#   1.37277343e+03 -5.67477254e+03]

# %%
y_pred = linreg.predict(X_test)

# %%
import numpy as np

#import metrics library
from sklearn import metrics

#print results of MAE
print(metrics.mean_absolute_error(y_test, y_pred))

# Print results of MSE
print(metrics.mean_squared_error(y_test, y_pred))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 17356.050142769713
# 433244073.0820257
# 20814.515922356342

# %% [markdown]
# ## GUI for Prediction

# %%
from sklearn import linear_model
import tkinter as tk 
import statsmodels.api as sm

df = pd.read_csv("../Data/Train_data_Update.csv", index_col = "Start_date")


X = df[['Days_Open','News_Count','Avg_Tmp','WeekDay','big_data_newsCount']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['Avg_Count']


# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)


# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 


# tkinter GUI
root= tk.Tk() 
 
canvas1 = tk.Canvas(root, width = 1200, height = 450)
canvas1.pack()

# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)

# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)

# with statsmodels
print_model = model.summary()
label_model = tk.Label(root, text=print_model, justify = 'center', relief = 'solid', bg='LightSkyBlue1')
canvas1.create_window(800, 220, window=label_model)


# New_Days_Open label and input box
label1 = tk.Label(root, text='Type Days Open: ')
canvas1.create_window(100, 100, window=label1)

entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)

# New_News_Count label and input box
label2 = tk.Label(root, text=' Type News Count: ')
canvas1.create_window(120, 120, window=label2)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

# New_Week_Day label and input box
label3 = tk.Label(root, text=' Type Week Day (0 = Monday): ')
canvas1.create_window(120, 120, window=label2)

entr3 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

# New_BD_News_Count and input box
label4 = tk.Label(root, text=' Type Big Data News Count: ')
canvas1.create_window(120, 120, window=label2)

entry4 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

# New_Avg_Temp and input box
label5 = tk.Label(root, text=' Type Average Temperature: ')
canvas1.create_window(120, 120, window=label2)

entry5 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)



def values(): 
    global New_Days_Open #our 1st input variable
    New_Interest_Rate = float(entry1.get()) 
    
    global New_News_Count #our 2nd input variable
    New_Unemployment_Rate = float(entry2.get()) 
    
    global New_Week_Day #our 2nd input variable
    New_Unemployment_Rate = float(entry2.get()) 
    
    global New_BD_News_Count #our 2nd input variable
    New_Unemployment_Rate = float(entry2.get()) 
    
    global New_Avg_Temp #our 2nd input variable
    New_Unemployment_Rate = float(entry2.get()) 
    
    Prediction_result  = ('Predicted Average Number of Visitors: ', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))
    label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
    canvas1.create_window(260, 280, window=label_Prediction)
    
button1 = tk.Button (root, text='Predict Average Number of Visitors',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(270, 150, window=button1)
 

root.mainloop()
# Out:
# Intercept:
#  58576.24875712459
# Coefficients:
#  [-2891.71610888    49.69532932   324.89951829   739.61073529
#   -287.43977387]
# C:\Users\Joey\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
