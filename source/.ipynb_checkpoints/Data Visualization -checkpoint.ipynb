# %%
# library
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("../Data/merge_weather_and_features.csv")

# %%
a = train.groupby('Year').mean()
a.reset_index(inplace = True)

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Count', 'avg_temp', 'high_temp', 'low_temp',
#        'temp_range', 'Portrait_temp', 'humidity', 'cloudAmount',
#        'hourSolarRadiation', 'hourSunshine', 'avg_windSpeed\r\n',
#        'high_windspeed', 'high_', 'evaporation_amount', 'rainfall',
#        'groundTemperature', 'Month', 'Day', 'Days_Open', 'News_Count',
#        'Vis_change_rate', 'big_data_newsCount', 'prev_count', 'mid_count',
#        'after_count', 'WeekDay', 'Avg_Count'],
#       dtype='object')

# %%
train.drop('Unnamed: 0',axis=1, inplace = True)

# %%
by_month = train.groupby('Month').mean()

# %%
by_month.reset_index(inplace = True)

# %%
by_day = train.groupby('Day').mean()
by_day.reset_index(inplace = True)

# %%
by_wkday = train.groupby('WeekDay').mean()
by_wkday.reset_index(inplace = True)

# %%
#draw plot for month and count
sns.set(style="whitegrid")
ax = sns.barplot(x="Month", y="Count", data=by_month).set_title('Total Average Visitors per Month', size = 14)

# %%
ax = sns.barplot(x= "Day", y="Count", data = by_day ).set_title('Total Average Visitors per Day of the Month', size = 14)

# %%
#return day name from number
def dayNameFromWeekday(weekday):
    days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
    return days[weekday]

# %%
by_wkday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 28 columns):
# WeekDay               4 non-null int64
# Year                  4 non-null float64
# Count                 4 non-null float64
# avg_temp              4 non-null float64
# high_temp             4 non-null float64
# low_temp              4 non-null float64
# temp_range            4 non-null float64
# Portrait_temp         4 non-null float64
# humidity              4 non-null float64
# cloudAmount           4 non-null float64
# hourSolarRadiation    4 non-null float64
# hourSunshine          4 non-null float64
# avg_windSpeed
#        4 non-null float64
# high_windspeed        4 non-null float64
# high_                 4 non-null float64
# evaporation_amount    4 non-null float64
# rainfall              4 non-null float64
# groundTemperature     4 non-null float64
# Month                 4 non-null float64
# Day                   4 non-null float64
# ...

# %%
by_wkday['WeekDay'] = by_wkday['WeekDay']

# %%
import datetime
weekDays = ("Wednesday","Thursday","Friday","Saturday")

# %%
by_wkday['WeekDay'] = weekDays

# %%
by_wkday
# Out:
#      WeekDay         Year          Count   avg_temp  high_temp   low_temp  \
# 0  Wednesday  2010.500000  121625.500000  16.426667  21.273333  12.200000
# 1   Thursday  2008.000000  140729.333333  18.824242  24.441667  14.451515
# 2     Friday  2009.363636  204308.090909  19.857576  25.488636  15.305000
# 3   Saturday  2010.166667  169016.500000  19.918434  25.608712  14.899495
#
#    temp_range  Portrait_temp   humidity  cloudAmount  ...     Month  \
# 0    9.073333      10.383333  68.586667     5.560000  ...  9.500000
# 1    9.990152      12.531818  73.138636     4.159091  ...  9.333333
# 2   10.233636      13.239545  71.008788     4.805152  ...  8.000000
# 3   10.709217      12.064646  66.236566     4.112449  ...  8.166667
#
#          Day  Days_Open  News_Count  Vis_change_rate  big_data_newsCount  \
# 0  13.500000   4.000000  152.500000        -0.987966          104.500000
# 1   6.666667   6.333333   63.000000        -0.254776           82.333333
# ...

# %%
by_wkday['WeekDay'][0:4]
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# Name: WeekDay, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

pal = sns.color_palette("Greens_d", len(by_wkday))
#rank = groupedvalues["total_bill"].argsort().argsort() 
g=sns.barplot(x='WeekDay',y='Count',data=by_wkday)

for index, row in by_wkday.iterrows():
    g.text(row.name,row.Count, round(row.Count), color='black', ha="center")

g.set_title('Total Visitor Average by Day of the Week', size = 17)
plt.show()

# %% [markdown]
# ### Average Day Visitors

# %% [markdown]
# #### Visitors vs Day of the Week

# %%
pal = sns.color_palette("Greens_d", len(by_wkday))
#rank = groupedvalues["total_bill"].argsort().argsort() 
g=sns.barplot(x='WeekDay',y='Count',data=by_wkday)

for index, row in by_wkday.iterrows():
    g.text(row.name,row.Count, round(row.Count), color='black', ha="center")

g.set_title('Total Visitor Average by Day of the Week', size = 17)
plt.show()

# %%
pal = sns.color_palette("Greens_d", len(by_wkday))
#rank = groupedvalues["total_bill"].argsort().argsort() 
g=sns.barplot(x='WeekDay',y='Avg_Count',data=by_wkday)

for index, row in by_wkday.iterrows():
    g.text(row.name,row.Avg_Count, round(row.Avg_Count), color='black', ha="center")

g.set_title('1 Day Visitor Average by Day of the Week', size = 17)
plt.show()

# %%
DayOnMonth = sns.barplot(x= "Day", y="Count", data = by_day ).set_title('Total Average Visitors per Day of the Month', size = 14)

# %%
AvgOnMonth = sns.barplot(x= "Day", y="Avg_Count", data = by_day ).set_title('1 Day Average Visitors per Day of the Month', size = 14)

# %% [markdown]
# #### Total Average Visitors per Month

# %%
#draw plot for month and count
sns.set(style="whitegrid")
ax = sns.barplot(x="Month", y="Count", data=by_month).set_title('Total Average Visitors per Month', size = 14)

# %% [markdown]
# #### 1 Day Average Visitors per Month

# %%
#draw plot for month and count
sns.set(style="whitegrid")
ax = sns.barplot(x="Month", y="Avg_Count", data=by_month).set_title('1 Day Average Visitors per Month', size = 14)

# %% [markdown]
# #### Total Average for Days Opened

# %%
by_dayOpen = train.groupby('Days_Open').mean()
by_dayOpen.reset_index(inplace = True)

# %%
#draw plot for month and count
sns.set(style="whitegrid")
ax = sns.barplot(x="Days_Open", y="Count", data=by_dayOpen).set_title('Total Average Visitors per Days Opened', size = 14)

# %%
ax = sns.barplot(x="Days_Open", y="Avg_Count", data=by_dayOpen).set_title('1 Day Average Visitors per Days Opened', size = 14)

# %%
g = sns.catplot(x="Days_Open", y="Avg_Count",
                  col="WeekDay",
                 data=train, kind="bar",
                 height=4, aspect=.7);
